# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="x6A6ry1kKUANYLlc0zBQ")
project = rf.workspace("ntnu-2wibj").project("seadronessee-odv2")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
# ...

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6362.1/8062.4 GB disk)

# %%
import os
os.environ["WANDB_MODE"] = "disabled"

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=/kaggle/input/msar-garuda/msar.yaml epochs=100 patience=25 imgsz=640 batch=48 augment=True half=True cache=True lr0=0.005 device=0,1 project=training_iteration_1 name=training_iteration_1
# Out:
# ...
# 100%|███████████████████████████████████████| 18.4M/18.4M [00:00<00:00, 165MB/s]
# Ultralytics 8.3.141 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#                                                         CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/kaggle/working/training_iteration_1/training_iteration_1/weights/best.pt conf=0.45 source=/kaggle/working/SeaDronesSee-ODV2-10/test/images
# Out:
# Ultralytics 8.3.141 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,414,735 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1075 /kaggle/working/SeaDronesSee-ODV2-10/test/images/1003_jpg.rf.cf93d0b3687d180f9561772e43907dcb.jpg: 448x640 1 boat, 48.9ms
# image 2/1075 /kaggle/working/SeaDronesSee-ODV2-10/test/images/1018_jpg.rf.bab1eed64169733297728f985c90100c.jpg: 640x448 2 boats, 47.9ms
# image 3/1075 /kaggle/working/SeaDronesSee-ODV2-10/test/images/1032_jpg.rf.d55bc3185e73ab9eab06dd50afd36761.jpg: 448x640 2 boats, 12.7ms
# image 4/1075 /kaggle/working/SeaDronesSee-ODV2-10/test/images/1036_jpg.rf.80b3745f8ed893e18dfe52e23f732fb3.jpg: 448x640 4 boats, 12.0ms
# image 5/1075 /kaggle/working/SeaDronesSee-ODV2-10/test/images/1037_jpg.rf.278361db91399a8b2306a4f0ed95a144.jpg: 448x640 3 boats, 12.0ms
# ...

# %%
# !zip -r iteration_1_results.zip /kaggle/working/runs/detect/predict
# Out:
#   adding: kaggle/working/runs/detect/predict/ (stored 0%)
#   adding: kaggle/working/runs/detect/predict/5552_jpg.rf.ce3cd9049230c62e66608c059caac9ea.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/predict/7539_jpg.rf.59a87f2fd74a35c4fcf901a3d15ba079.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/predict/7474_jpg.rf.58cc37e32b7ae9c0f9f57bd18279e15a.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/predict/8375_jpg.rf.bc3f6552d877db98099bf10a0e27cb86.jpg (deflated 9%)
#   adding: kaggle/working/runs/detect/predict/1771_jpg.rf.3b25cccea2c9dc284ffdd31f6e2176d5.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/predict/2642_jpg.rf.5b472d1247ce5f350c16f1a77f0b0285.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/predict/3517_jpg.rf.1f37ca91ae541f6f8f7586f0ffcddde0.jpg (deflated 7%)
#   adding: kaggle/working/runs/detect/predict/8084_jpg.rf.e6a0f81e0c2e8f7c4a7ec81df62411ff.jpg (deflated 6%)
# ...

# %%
# !zip -r iteration_1_metrics.zip /kaggle/working/training_iteration_1/training_iteration_1
# Out:
#   adding: kaggle/working/training_iteration_1/training_iteration_1/ (stored 0%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/labels.jpg (deflated 37%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/confusion_matrix_normalized.png (deflated 21%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/val_batch1_labels.jpg (deflated 8%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/PR_curve.png (deflated 9%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/train_batch1.jpg (deflated 5%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/args.yaml (deflated 53%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/train_batch13772.jpg (deflated 14%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/R_curve.png (deflated 9%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/F1_curve.png (deflated 8%)
# ...
